# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import  train_test_split
from sklearn.metrics import accuracy_score
import matplotlib
from matplotlib import pyplot as plt
from sklearn import preprocessing 
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
import seaborn as sns

# %%
df = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Aug20exclusion5kd_Train.csv',sep='|' )

# %%
df1 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Sep20exclusion5kd_Train.csv',sep='|' )

# %%
df2 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Oct20exclusion5kd_Train.csv',sep='|' )

# %%
df3 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Nov20exclusion5kd_Train.csv',sep='|' )

# %%
df4 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Dec20exclusion5kd_Train.csv',sep='|' )

# %%
df5 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_jan21exclusion5kd_Train.csv',sep='|' )

# %%
df6 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_feb21exclusion5kd_Train.csv',sep='|' )

# %%
df7 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Mar21exclusion5kd_Train.csv',sep='|' )

# %%
df8 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Apr21exclusion5kd_Train.csv',sep='|' )

# %%
df9 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_May21exclusion5kd_Train.csv',sep='|' )

# %%
df10 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Jun21exclusion5kd_Train.csv',sep='|' )

# %%
df11 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Jul21exclusion5kd_Train.csv',sep='|' )

# %%
df12 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Aug21exclusion5kd_Train.csv',sep='|' )

# %%
df13 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Sep21exclusion5kd_Train.csv',sep='|' )

# %%
df14 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Oct21exclusion5kd_Train.csv',sep='|' )

# %%
df15 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Nov21exclusion5kd_Train_Part1.csv',sep='|' )

# %%
df16 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Nov21exclusion5kd_Train_Part2.csv',sep='|' )

# %%
df16=df16.append(df15,ignore_index= True)

# %%
df16=df16.drop(['ranking'],axis=1)

# %%
df17 = pd.read_csv('C:/Suraj/Models/CPM/Train Data Repository- Voluntary/Voluntary_Postpaid_Dec21exclusion5kd_Train.csv',sep='|' )

# %%
df=df.append(df1,ignore_index= True)

# %%
df=df.append(df2,ignore_index= True)

# %%
df=df.append(df3,ignore_index= True)

# %%
df=df.append(df4,ignore_index= True)

# %%
df=df.append(df5,ignore_index= True)

# %%
df=df.append(df6,ignore_index= True)

# %%
df=df.append(df7,ignore_index= True)

# %%
df=df.append(df8,ignore_index= True)

# %%
df=df.append(df9,ignore_index= True)

# %%
df=df.append(df10,ignore_index= True)

# %%
df=df.append(df11,ignore_index= True)

# %%
df=df.append(df12,ignore_index= True)

# %%
df=df.append(df13,ignore_index= True)

# %%
df=df.append(df14,ignore_index= True)

# %%
#df=df.append(df15,ignore_index= True)

# %%
df=df.append(df16,ignore_index= True)

# %%
df=df.append(df17,ignore_index= True)

# %%
df.shape
# Out:
# (5419971, 415)

# %%
df=df.drop(['subscriber_id',
'subscription_no',
'contract_no'

],axis=1)

# %%
df['ga_cont_gender'].replace('Male','M',inplace=True)
df['ga_cont_gender'].replace('Female','F',inplace=True)

# %%
df.groupby('ga_cont_gender').count()
# Out:
#                 tabs_status  category_code  subscription_type  \
# ga_cont_gender
# EGYPT                     8              8                  8
# F                    964052         962461             964052
# F                    644436         643845             644436
# M                   2213183        2208960            2213183
# M                   1588436        1587861            1588436
# X                      5444           5444               5444
# X                      4327           4327               4327
#
#                 ga_cont_nationality  customer_age  ga_segment  \
# ga_cont_gender
# EGYPT                             8             8           8
# F                            963858        964052      964052
# F                            644436        644436      644436
# M                           2212899       2213183     2213183
# M                           1588436       1588436     1588436
# ...

# %%
df.replace(np.NaN,0,inplace=True)

# %%
for feature in df.columns: 
    if df[feature].dtype == 'object': 
        df[feature] = pd.Categorical(df[feature]).codes

# %%
df.isnull().sum()
# Out:
# tabs_status           NaN
# category_code         NaN
# subscription_type     NaN
# ga_cont_nationality   NaN
# customer_age          NaN
#                        ..
# amt_paid_m1           NaN
# payment_ratios_m3     NaN
# payment_ratios_m2     NaN
# payment_ratios_m1     NaN
# churn_flag            NaN
# Length: 412, dtype: float64

# %%
df.columns
# Out:
# Index(['tabs_status', 'category_code', 'subscription_type',
#        'ga_cont_nationality', 'customer_age', 'ga_cont_gender', 'ga_segment',
#        'last_handset_vendor', 'customer_aon', 'apple_device',
#        ...
#        'inv_amt_m3', 'inv_amt_m2', 'inv_amt_m1', 'amt_paid_m3', 'amt_paid_m2',
#        'amt_paid_m1', 'payment_ratios_m3', 'payment_ratios_m2',
#        'payment_ratios_m1', 'churn_flag'],
#       dtype='object', length=412)

# %%
df.shape
# Out:
# (5419971, 412)

# %%
x=df.drop(['churn_flag'],axis=1)
y=df.pop('churn_flag')
y_main=y

# %%
x.shape
# Out:
# (5419971, 411)

# %%
y.value_counts()
# Out:
# 0    5398055
# 1      21916
# Name: churn_flag, dtype: int64

# %%
from collections import Counter
import collections
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

from imblearn.under_sampling import RandomUnderSampler
os = RandomUnderSampler(sampling_strategy='majority') #minority auto all 'not minority' 'majority'
#os = ClusterCentroids(sampling_strategy='all')

x, y = os.fit_sample(x, y)
print('Original dataset shape {}'.format(Counter(y)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-152f407f2914> in <module>
#       8 #os = ClusterCentroids(sampling_strategy='all')
#       9
# ---> 10 x, y = os.fit_sample(x, y)
#      11 print('Original dataset shape {}'.format(Counter(y)))
#
# NameError: name 'x' is not defined

# %%
y.value_counts()
# Out:
# 1    21916
# 0    21916
# Name: churn_flag, dtype: int64

# %%
x.shape
# Out:
# (43832, 411)

# %%
scaled_x = x

# %%
from sklearn.preprocessing import StandardScaler #MinMaxScaler # StandardScaler # MinMaxScaler
X = StandardScaler()
scaled_x = X.fit_transform(scaled_x)

# %%
x_train = scaled_x
y_train = y

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier


model = []
#model.append(LogisticRegression())
#model.append(RidgeClassifier())
#model.append(KNeighborsClassifier())
#model.append(SVC())
#model.append(BaggingClassifier())
#model.append(RandomForestClassifier())
#model.append(XGBClassifier(random_state=42,max_depth=5,max_features ='auto', scale_pos_weight=200, n_estimators=500, subsample= 1.0,n_jobs=-1))
#model.append(GradientBoostingClassifier())

model.append(XGBClassifier(random_state=42,n_estimators=500,n_jobs=-1))
#model.append(XGBClassifier(random_state=42,scale_pos_weight=203.58,n_estimators=500,n_jobs=-1))

#Model: XGBClassifier Best: 0.034381 using {'max_depth': 5, 'max_features': 'auto', 'n_estimators': 500, 'scale_pos_weight': 100, 'subsample': 1.0}

# %%
#models

# %%
# model validation Apr21 prediction and Sept20Oct20Nov20Dec20Jan21Feb21 data input

# %%
Oct_Data = pd.read_csv('C:/Suraj/Models/CPM/Feb22 Data/Voluntary_Postpaid_Jan22exclusion5kd.csv',sep='|' )

# %%
#Oct_Data1 = pd.read_csv('C:/Suraj/Models/CPM/Jan22 Data/Voluntary_Postpaid_Dec21exclusion5kd_Part2.csv',sep='|' )

# %%
#Oct_Data=Oct_Data.append(Oct_Data1,ignore_index= True)

# %%
Oct_Data.shape
# Out:
# (326521, 414)

# %%
#Aug_Data = pd.read_csv('C:/Suraj/Models/CPM/Aug Data/Voluntary_Postpaid_Aug.csv',sep='|' )

#Oct_Data = pd.read_csv('C:/Suraj/Models/CPM/Dec21 Data/Voluntary_Postpaid_Nov21exclusion5kd.csv',sep='|' )
Oct_Data_copy = Oct_Data

# %%
Oct_Data=Oct_Data.drop(['subscriber_id',
'subscription_no',
'contract_no'],axis=1)

# %%
Oct_Data.shape
# Out:
# (326521, 411)

# %%
Oct_Data['ga_cont_gender'].replace('Male','M',inplace=True)
Oct_Data['ga_cont_gender'].replace('Female','F',inplace=True)

# %%
Oct_Data.replace(np.NaN,0,inplace=True)
for feature in Oct_Data.columns: 
    if Oct_Data[feature].dtype == 'object': 
        Oct_Data[feature] = pd.Categorical(Oct_Data[feature]).codes

# %%
x_test_Oct=Oct_Data

# %%
#x_test_Oct=Oct_Data.drop(['churn_flag'],axis=1)
#y_test_Oct=Oct_Data.pop('churn_flag')

# %%
#from sklearn.preprocessing import StandardScaler #MinMaxScaler # StandardScaler # MinMaxScaler
#X = StandardScaler()
x_test_Oct = X.transform(x_test_Oct)

# %%
#No .values used
#x_test_Oct = x_test_Oct

# %%
#y.shape

# %%
for i in model:
    print(i)
    reg_dt_model = i
    reg_dt_model.fit(scaled_x, y)
# Out:
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=500, n_jobs=-1, num_parallel_tree=None,
#               random_state=42, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None)
# ...

# %%
ytest_predict = reg_dt_model.predict(x_test_Oct)
#print(classification_report(y, ytest_predict))

# %%
predictions_proba_score=reg_dt_model.predict_proba(x_test_Oct)
predictions_proba_score=pd.DataFrame(predictions_proba_score[:,1])
predictions_proba_score=predictions_proba_score.rename(columns={0:'Predicted'})

# %%
Oct_Data_copy['Probability']=predictions_proba_score['Predicted']

# %%
Oct_Data_copy['Decile']=pd.qcut(Oct_Data_copy['Probability'],20,duplicates='drop',labels = range(1,21))

# %%
Oct_Data_copy.groupby('Decile').agg(['count','sum'])
# Out:
#        subscriber_id               subscription_no                contract_no  \
#                count           sum           count            sum       count
# Decile
# 1              16327  302020721972           16327  1526229047680       16327
# 2              16326  333045907302           16326  1513180183861       16326
# 3              16326  353033671087           16326  1507031511233       16326
# 4              16326  366984411318           16326  1499544365207       16326
# 5              16326  381788218022           16326  1494434803016       16326
# 6              16326  391531035211           16326  1490138868418       16326
# 7              16326  404489358080           16326  1483677912526       16326
# 8              16326  417498189866           16326  1479122236290       16326
# 9              16326  422850196523           16326  1472154656801       16326
# 10             16326  436905372782           16326  1466339465527       16326
# ...

# %%
Oct_Data_copy.head()
# Out:
#    subscriber_id  subscription_no  contract_no tabs_status category_code  \
# 0        8011490         99714094       349139        CONN           PKU
# 1       53826764         50709058   1000009441        CONN           PKU
# 2       28713067         97911154       231148        CONN           PKU
# 3       55526465         99866333      2575826        CONN           1CK
# 4       17262340         99200433       382874        CONN           1CN
#
#   subscription_type   ga_cont_nationality  customer_age ga_cont_gender  \
# 0             VOICE               Kuwaiti            53            M
# 1             MIXED               Kuwaiti            38           Male
# 2             VOICE               Kuwaiti            54            F
# 3             MIXED               Kuwaiti            57         Female
# 4             MIXED  Syrian Arab Republic            52           Male
#
#   ga_segment  ... inv_amt_m2  inv_amt_m1  amt_paid_m3  amt_paid_m2  \
# ...

# %%
import shap
# compute SHAP values
explainer = shap.TreeExplainer(reg_dt_model)
shap_values = explainer.shap_values(x_test_Oct)

# %%
importances = reg_dt_model.feature_importances_
#importances = model.best_estimator_.feature_importances_
import matplotlib.pyplot as plt
print(reg_dt_model.feature_importances_)
feat_importances = pd.Series(reg_dt_model.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()
# Out:
# [0.0000000e+00 1.9503623e-03 1.9025257e-02 5.1284092e-03 2.3083177e-03
#  2.8044165e-03 2.6064832e-03 2.7303151e-03 8.3001088e-03 2.1213570e-03
#  1.8213515e-03 1.5502087e-03 5.7886844e-04 1.3824168e-02 1.9493868e-03
#  4.3980755e-02 1.9944231e-03 1.3176772e-03 2.4630313e-03 1.7090176e-03
#  2.4037138e-03 4.8876060e-03 1.8561702e-03 1.7104533e-03 6.7577213e-03
#  2.4275112e-03 2.2916179e-03 1.9460057e-03 1.9655516e-03 4.8591886e-03
#  2.0792030e-03 1.7764204e-03 2.8026153e-03 6.5409094e-03 5.6118905e-03
#  3.5448878e-03 2.5101402e-03 2.8690705e-03 1.2104187e-02 1.9579327e-03
#  1.9181431e-03 1.8570013e-03 2.5384896e-03 2.0527253e-03 2.3754339e-03
#  2.0135602e-03 2.3579202e-03 1.9403266e-03 1.5771104e-03 1.7371646e-03
#  1.9215499e-03 2.1706030e-03 1.6714595e-03 1.8368444e-03 1.9738427e-03
#  1.7107909e-03 2.4119762e-03 2.3251020e-03 2.0058835e-03 1.9064926e-03
#  0.0000000e+00 1.5976134e-03 1.8898129e-03 1.6477775e-03 1.7712937e-03
# ...

# %%
X_columns = x.columns
imp_feat=pd.DataFrame(list(zip(X_columns, reg_dt_model.feature_importances_)))

#models
#imp_feat.to_csv(r'C:\Suraj\Models\CPM\Aug Data\xgboostundersamplingseptooct.csv', index = False)

# %%
#!/usr/bin/env python
# Python 3.6.4

import numpy as np
import pandas as pd
import iml
import xgboost
import shap
from tqdm import tqdm


def calculate_top_contributors(shap_values, features=None, feature_names=None, use_abs=False, return_df=False,
                               n_features=5):
    """ Adapted from the SHAP package for visualizing the contributions of features towards a prediction.
        https://github.com/slundberg/shap

        Args:
            shap_values: np.array of floats
            features: pandas.core.series.Series, the data with the values
            feature_names: list, all the feature names/ column names
            use_abs: bool, if True, will sort the data by the absolute value of the feature effect
            return_df: bool, if True, will return a pandas dataframe, else will return a list of feature, effect, value
            n_features: int, the number of features to report on. If it equals -1 it will return the entire dataframe

        Returns:
            if return_df is True: returns a pandas dataframe
            if return_df is False: returns a flattened list by name, effect, and value
        """
    assert not type(shap_values) == list, "The shap_values arg looks looks multi output, try shap_values[i]."
    assert len(shap_values.shape) == 1, "Expected just one row. Please only submit one row at a time."

    shap_values = np.reshape(shap_values, (1, len(shap_values)))
    instance = iml.Instance(np.zeros((1, len(feature_names))), features)
    link = iml.links.convert_to_link('identity')

    # explanation obj
    expl = iml.explanations.AdditiveExplanation(
        shap_values[0, -1],                 # base value
        np.sum(shap_values[0, :]),          # this row's prediction value
        shap_values[0, :-1],                # matrix
        None,
        instance,                           # <iml.common.Instance object >
        link,                               # 'identity'
        iml.Model(None, ["output value"]),  # <iml.common.Model object >
        iml.datatypes.DenseData(np.zeros((1, len(feature_names))), list(feature_names))
    )

    # Get the name, effect and value for each feature, if there was an effect
    features_ = {}
    for i in range(len(expl.data.group_names)-1):
        if expl.effects[i] != 0:
            features_[i] = {
                "effect": ensure_not_numpy(expl.effects[i]),
                "value": ensure_not_numpy(expl.instance.group_display_values[i]),
                "name": expl.data.group_names[i]
            }

    effect_df = pd.DataFrame([v for k, v in features_.items()])

    if use_abs:  # get the absolute value of effect
        effect_df['abs_effect'] = effect_df['effect'].apply(np.abs)
        effect_df.sort_values('abs_effect', ascending=False, inplace=True)
    else:
        effect_df.sort_values('effect', ascending=False, inplace=True)
    if not n_features == -1:
        effect_df = effect_df.head(n_features)
    if return_df:
        return effect_df.reset_index(drop=True)
    else:
        list_of_info = list(zip(effect_df.name, effect_df.effect, effect_df.value))
        effect_list = list(sum(list_of_info, ()))  # flattens the list of tuples
        return effect_list


def create_prediction_factors_df(contribs, X, clf,featurename1):
    """Takes in the report df, contribs, previous eval df, and the model
    Args:
        contribs: numpy matrix
        X: pandas DataFrame
        clf: XGBoost classifier model

    Returns:
        pd.DataFrame of the factors
    """

    factors = []
    for i, row in tqdm(X.iterrows()):
        vals = calculate_top_contributors(shap_values=contribs[i, :], features=X.iloc[i, :],
                                          feature_names=featurename1)
        factors.append(vals)
    df = pd.DataFrame(factors, columns=['F1', 'F1_effect', 'F1_value', 'F2', 'F2_effect', 'F2_value',
                                        'F3', 'F3_effect', 'F3_value', 'F4', 'F4_effect', 'F4_value',
                                        'F5', 'F5_effect', 'F5_value',])
    return df


def ensure_not_numpy(x):
    """Helper function borrowed from the iml package"""
    if isinstance(x, bytes):
        return x.decode()
    elif isinstance(x, np.str):
        return str(x)
    elif isinstance(x, np.generic):
        return float(np.asscalar(x))
    else:
        return x


#if __name__ == '__main__':

# %%
x_test_Oct_123=Oct_Data

# %%
x_test_Oct_123.head()
# Out:
#    tabs_status  category_code  subscription_type  ga_cont_nationality  \
# 0            0             32                  1                   97
# 1            0             32                  0                   97
# 2            0             32                  1                   97
# 3            0              1                  0                   97
# 4            0              2                  0                  157
#
#    customer_age  ga_cont_gender  ga_segment  last_handset_vendor  \
# 0            53               4           0                    4
# 1            38               3           0                   63
# 2            54               2           0                    4
# 3            57               1           0                    0
# 4            52               3           0                    4
#
#    customer_aon  apple_device  ...  twog_flag  inv_amt_m3  inv_amt_m2  \
# 0           298             0  ...        0.0       22.08      19.885
# ...

# %%
feature_names1=imp_feat.iloc[:,0]

# %%
    # for just the first observation
    vals = calculate_top_contributors(shap_values=shap_values[0, :], features=x_test_Oct_123.iloc[0, :],
                                          feature_names=feature_names1, use_abs=False)
# Out:
# np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead

# %%
vals
# Out:
# ['total_commitments',
#  0.6300638914108276,
#  0.0,
#  'computer_and_electronics_cnt',
#  0.44947463274002075,
#  0.0,
#  'avg_t_vc_local_offnet_tot_kd',
#  0.3727690875530243,
#  7.413333333333333,
#  't_data_tot_vol_m1',
#  0.3482595682144165,
#  0.0,
#  'avg_t_vc_local_onnet_tot_kd',
#  0.2532716691493988,
#  4.426666666666667]

# %%
    # or as a dataframe
    factors_df = create_prediction_factors_df(shap_values, x_test_Oct_123, clf=reg_dt_model,featurename1=feature_names1)
# Out:
# 0it [00:00, ?it/s]np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
# 326521it [46:34, 116.83it/s]

# %%
factors_df
# Out:
#                                  F1  F1_effect  F1_value  \
# 0                 total_commitments   0.630064       0.0
# 1                 total_commitments   0.605499       0.0
# 2                 total_commitments   0.765659       0.0
# 3       t_vc_local_onnet_tot_vol_m1   1.257080       0.0
# 4                 t_data_tot_vol_m1   0.415190       0.0
# ...                             ...        ...       ...
# 326516            total_commitments   0.659738       0.0
# 326517  t_vc_local_onnet_tot_vol_m1   0.930855       0.0
# 326518            total_commitments   0.877380       0.0
# 326519                 customer_aon   1.538551      23.0
# 326520            total_commitments   0.621206       0.0
#
#                                      F2  F2_effect   F2_value  \
# 0          computer_and_electronics_cnt   0.449475      0.000
# 1          computer_and_electronics_cnt   0.428758      0.000
# 2            t_vc_local_onnet_tot_kd_m1   0.442092     13.960
# ...

# %%
Oct_Data_copy1=pd.concat([Oct_Data_copy,factors_df],axis=1)

# %%
Oct_Data_copy1
# Out:
#         subscriber_id  subscription_no  contract_no tabs_status category_code  \
# 0             8011490         99714094       349139        CONN           PKU
# 1            53826764         50709058   1000009441        CONN           PKU
# 2            28713067         97911154       231148        CONN           PKU
# 3            55526465         99866333      2575826        CONN           1CK
# 4            17262340         99200433       382874        CONN           1CN
# ...               ...              ...          ...         ...           ...
# 326516         847238         99549969       269214        CONN           PVB
# 326517       53142185         91119101   1000153206        CONN           PKU
# 326518       53741759         55433413      4688059        CONN           PKU
# 326519       52952662         50771006   1000167137        CONN           PNK
# 326520       52039903         99276680       123760        CONN           PKU
#
# ...

# %% [markdown]
# # just to export the whole base

# %%
Aug_Prediction = pd.DataFrame(Oct_Data_copy1)

# %%
Aug_Prediction.groupby('Decile').agg(['count','sum'])
# Out:
#        subscriber_id               subscription_no                contract_no  \
#                count           sum           count            sum       count
# Decile
# 1              16327  302020721972           16327  1526229047680       16327
# 2              16326  333045907302           16326  1513180183861       16326
# 3              16326  353033671087           16326  1507031511233       16326
# 4              16326  366984411318           16326  1499544365207       16326
# 5              16326  381788218022           16326  1494434803016       16326
# 6              16326  391531035211           16326  1490138868418       16326
# 7              16326  404489358080           16326  1483677912526       16326
# 8              16326  417498189866           16326  1479122236290       16326
# 9              16326  422850196523           16326  1472154656801       16326
# 10             16326  436905372782           16326  1466339465527       16326
# ...

# %%
Aug_Prediction_selected_columns_fulldecile = Aug_Prediction[["subscriber_id","subscription_no","avg_revenue","customer_aon","Probability","Decile","F1","F2","F3","F4","F5"]]

# %%
Aug_Prediction_selected_columns_fulldecile.to_csv(r'C:\Suraj\Models\CPM\Feb22 Data\Feb22_Predictions_fulldecile.csv', index = False)

# %%
Aug_Prediction_selected_columns_fulldecile
# Out:
#         subscriber_id  subscription_no  avg_revenue  customer_aon  \
# 0             8011490         99714094    19.193333           298
# 1            53826764         50709058    14.000000            16
# 2            28713067         97911154    28.545000           205
# 3            55526465         99866333    15.000000             2
# 4            17262340         99200433    36.100000            17
# ...               ...              ...          ...           ...
# 326516         847238         99549969    24.880000           132
# 326517       53142185         91119101    19.216333            12
# 326518       53741759         55433413    14.033333            16
# 326519       52952662         50771006    77.433333            23
# 326520       52039903         99276680    25.000000            27
#
#         Probability Decile                           F1  \
# 0          0.028279      4            total_commitments
# 1          0.446903     15            total_commitments
# ...

# %%
Aug_Prediction_selected_columns_fulldecile_top1920 = pd.DataFrame(Aug_Prediction_selected_columns_fulldecile[Aug_Prediction_selected_columns_fulldecile.Decile >= 20] )

# %%
Aug_Prediction_selected_columns_fulldecile_top1920
# Out:
#         subscriber_id  subscription_no  avg_revenue  customer_aon  \
# 36           42962762         99671345    10.220000            53
# 51           52954649         51663960    10.000000            23
# 59           54822127         99642619    10.150000             7
# 64           52921830         92293926    48.000000            23
# 79           46094226         99016967    38.000000            17
# ...               ...              ...          ...           ...
# 326451       54848682         94955954    10.000000             7
# 326461       54482095         66606113    15.000000            12
# 326469       54023044         97870220    41.309667            14
# 326488       52610734         97776770    13.033333            24
# 326517       53142185         91119101    19.216333            12
#
#         Probability Decile                           F1  \
# 36         0.959884     20            total_commitments
# 51         0.940158     20               payment_ratios
# ...

# %%
#Aug_Prediction_final = pd.DataFrame (Aug_Prediction_selected_columns_fulldecile_top1920[Aug_Prediction_selected_columns_fulldecile_top1920.Probability >= 0.95 ])

# %%
Aug_Prediction_final=Aug_Prediction_selected_columns_fulldecile_top1920

# %%
Aug_Prediction_final
# Out:
#         subscriber_id  subscription_no  avg_revenue  customer_aon  \
# 36           42962762         99671345    10.220000            53
# 51           52954649         51663960    10.000000            23
# 59           54822127         99642619    10.150000             7
# 64           52921830         92293926    48.000000            23
# 79           46094226         99016967    38.000000            17
# ...               ...              ...          ...           ...
# 326451       54848682         94955954    10.000000             7
# 326461       54482095         66606113    15.000000            12
# 326469       54023044         97870220    41.309667            14
# 326488       52610734         97776770    13.033333            24
# 326517       53142185         91119101    19.216333            12
#
#         Probability Decile                           F1  \
# 36         0.959884     20            total_commitments
# 51         0.940158     20               payment_ratios
# ...

# %%
Aug_Prediction_final['AONCAT']= 'Others'

# %%
Aug_Prediction_final.loc[((Aug_Prediction_final['customer_aon']>=0) & (Aug_Prediction_final['customer_aon'] <6)),'AONCAT'] = '0-6'
Aug_Prediction_final.loc[((Aug_Prediction_final['customer_aon']>=6) & (Aug_Prediction_final['customer_aon'] <12)),'AONCAT'] = '6-12'
Aug_Prediction_final.loc[((Aug_Prediction_final['customer_aon']>=12) & (Aug_Prediction_final['customer_aon'] <18)),'AONCAT'] = '12-18'
Aug_Prediction_final.loc[((Aug_Prediction_final['customer_aon']>=18) & (Aug_Prediction_final['customer_aon'] <24)),'AONCAT'] = '18-24'
Aug_Prediction_final.loc[((Aug_Prediction_final['customer_aon']>=24) & (Aug_Prediction_final['customer_aon'] <36)),'AONCAT'] = '24-36'
Aug_Prediction_final.loc[((Aug_Prediction_final['customer_aon']>=36)),'AONCAT'] = '36+'

# %%
print(Aug_Prediction_final['AONCAT'].value_counts())
# Out:
# 36+      5011
# 0-6      3589
# 24-36    3255
# 12-18    1739
# 6-12     1486
# 18-24    1246
# Name: AONCAT, dtype: int64

# %%
Aug_Prediction_final['ARPUCAT']= 'Others'

# %%
Aug_Prediction_final.loc[((Aug_Prediction_final['avg_revenue']>=0) & (Aug_Prediction_final['avg_revenue'] <6)),'ARPUCAT'] = '0-6'
Aug_Prediction_final.loc[((Aug_Prediction_final['avg_revenue']>=6) & (Aug_Prediction_final['avg_revenue'] <12)),'ARPUCAT'] = '6-12'
Aug_Prediction_final.loc[((Aug_Prediction_final['avg_revenue']>=12) & (Aug_Prediction_final['avg_revenue'] <18)),'ARPUCAT'] = '12-18'
Aug_Prediction_final.loc[((Aug_Prediction_final['avg_revenue']>=18) & (Aug_Prediction_final['avg_revenue'] <24)),'ARPUCAT'] = '18-24'
Aug_Prediction_final.loc[((Aug_Prediction_final['avg_revenue']>=24) & (Aug_Prediction_final['avg_revenue'] <36)),'ARPUCAT'] = '24-36'
Aug_Prediction_final.loc[((Aug_Prediction_final['avg_revenue']>=36)),'ARPUCAT'] = '36+'
print (Aug_Prediction_final['ARPUCAT'].value_counts())
# Out:
# 36+      4614
# 24-36    3714
# 12-18    3129
# 6-12     2597
# 18-24    2155
# 0-6       117
# Name: ARPUCAT, dtype: int64

# %%
from sklearn.model_selection import train_test_split
TGData, CGData = train_test_split(Aug_Prediction_final,test_size=0.2, random_state=42,
                                 stratify=Aug_Prediction_final[['ARPUCAT']]) #,'AONCAT','ARPUCAT'

# %%
CGData
# Out:
#         subscriber_id  subscription_no  avg_revenue  customer_aon  \
# 63243         1144315         96668422    33.616667           130
# 57387        54846313         98794915    42.000000             7
# 189774        3055320         99667793    52.041333           100
# 54790        13331425         99256668    30.233333            99
# 192941       40841140         50918889    29.666667            52
# ...               ...              ...          ...           ...
# 203964       55316536         92209262    10.000000             3
# 320550         710182         97777378    61.146667           108
# 179178       54348236         67096648    13.033333             3
# 254981        3168232         99736383    25.583333           293
# 255168       54276752         99183923    10.000000            13
#
#         Probability Decile                           F1  \
# 63243      0.921446     20            total_commitments
# 57387      0.907905     20  t_vc_local_onnet_tot_vol_m1
# ...

# %%
TGData
# Out:
#         subscriber_id  subscription_no  avg_revenue  customer_aon  \
# 60142         7962937         97930057    27.410000            18
# 253038       34284944         99337658    21.500000            14
# 58165        35617619         94775558    48.217333            70
# 53837        55361678         50466610    20.416667             3
# 32499        50827643         50102020    10.500000            33
# ...               ...              ...          ...           ...
# 11736        41747493         97228559    19.850000            57
# 24177         2660258         99333933    10.000000            26
# 304054         675677         99774580    18.433333           247
# 37892        52555936         97777765    41.374333             9
# 323011       51961478         50777254    25.900000            27
#
#         Probability Decile                           F1  \
# 60142      0.927621     20            total_commitments
# 253038     0.967270     20            total_commitments
# ...

# %%
CGData['Type']= 'Control'
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
TGData['Type']= 'Target'
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Aug_Prediction_final_final=CGData

# %%
Aug_Prediction_final_final=Aug_Prediction_final_final.append(TGData,ignore_index= True)

# %%
Aug_Prediction_final_final
# Out:
#        subscriber_id  subscription_no  avg_revenue  customer_aon  Probability  \
# 0            1144315         96668422    33.616667           130     0.921446
# 1           54846313         98794915    42.000000             7     0.907905
# 2            3055320         99667793    52.041333           100     0.923126
# 3           13331425         99256668    30.233333            99     0.939949
# 4           40841140         50918889    29.666667            52     0.907943
# ...              ...              ...          ...           ...          ...
# 16321       41747493         97228559    19.850000            57     0.986837
# 16322        2660258         99333933    10.000000            26     0.962623
# 16323         675677         99774580    18.433333           247     0.938728
# 16324       52555936         97777765    41.374333             9     0.967211
# 16325       51961478         50777254    25.900000            27     0.955511
#
# ...

# %%
Aug_Prediction_final_final.to_csv(r'C:\Suraj\Models\CPM\Feb22 Data\Feb22_Predictions.csv',sep='|', index = False)

# %%
#CGData.to_csv(r'C:\Suraj\Models\CPM\Oct21 Data\Oct21_Predictions_control.csv', index = False)

# %%
#TGData.to_csv(r'C:\Suraj\Models\CPM\Oct21 Data\Oct21_Predictions_target.csv', index = False)

# %% [markdown]
# # END

# %%
df = pd.read_csv('C:/Suraj/Models/CPM/Oct21 Data/upload_Oct21_scoring.csv',sep='|' )

# %%
conda update --all

# %%
Aug_Prediction_final.head()

# %%
Aug_Prediction_selected_columns_fulldecile.to_csv(r'C:\Suraj\Models\CPM\Sep21 Data\Sep21_Predictions_fulldecile.csv', index = False)

# %% [markdown]
# # just to export the whole base end

# %%
Aug_Prediction = pd.DataFrame(Oct_Data_copy1[Oct_Data_copy1.Decile >= 13] )

# %%
Aug_Prediction_selected_columns_top2decile = Aug_Prediction[["subscriber_id","subscription_no","avg_revenue","Probability","F1","F2","F3","F4","F5"]]

# %%
Aug_Prediction_selected_columns_top2decile.to_csv(r'C:\Suraj\Models\CPM\Sep21 Data\Sep21_Predictions_top2decile.csv', index = False)

# %% [markdown]
# # this is for testing purpose

# %% [markdown]
# June_Prediction = pd.DataFrame(Oct_Data_copy1[Oct_Data_copy1.Decile >= 19] )

# %% [markdown]
# June_Prediction_selected_columns = June_Prediction[["subscriber_id","subscription_no","avg_revenue","Probability","Decile","F1","F2","F3","F4","F5"]]

# %% [markdown]
# June_Prediction_final = June_Prediction_selected_columns.copy()

# %% [markdown]
# June_Prediction_final.to_csv(r'C:\Suraj\Models\CPM\Jun21 Data\June21_Predictions_1920deciles.csv', index = False)

# %% [markdown]
# # Testig purpose end

# %%
Aug_Prediction = pd.DataFrame(Aug_Prediction[Aug_Prediction.Probability >= 0.90 ])

# %%
Aug_Prediction

# %%
Aug_Prediction_selected_columns = Aug_Prediction[["subscriber_id","subscription_no","avg_revenue","Probability","F1","F2","F3","F4","F5"]]

# %%
Aug_Prediction_final = Aug_Prediction_selected_columns.copy()

# %%
Aug_Prediction_final

# %%
Aug_Prediction_final.to_csv(r'C:\Suraj\Models\CPM\Aug21 Data\Aug21_Predictions_top2decile.csv', index = False)
